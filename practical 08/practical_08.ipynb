# %% [markdown]
# # Machine Learning- Python

# %% [markdown]
# **Scale**
#
# What is kilograms compared to meters? Or altitude compared to
# time?
# The answer to this problem is scaling. We can scale data into
# new values that are easier to compare.

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()

df=pandas.read_csv("data.csv")
X= df=[['weight','Volume']]
scaledX=scale.fit_transform(X)
print(scaledX)

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StanadrdScaler
scale=StandardScaler()

df=pandas.read_csv("data.csv")

x=df[['weight','volume']]
y=df['CO2']

scaledX= scale.transform([[2300,1.3]])
predicatedCO2=regr.predict([scaled[0]])
print(predicatedCO2)

# %% [markdown]
# **Train/Test**

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x=numpy.random.normal(3,1,100)
y=numpy.random.normal(150,40,100)/x

plt.scatter(x,y)
plt.show()


#Split Into Train/Test
#The training set should be a random selection of 80% of
#the original data.
#The testing set should be the remaining 20%.

train_x=x[:80]
train_y=y[:80]

test_x=x[80:]
test_y=y[80:]

#Display the Training Set
plt.scatter(train_x, train_y)
plt.show()

#Display the Testing Set
plt.scatter(test_x, test_y)
plt.show()

# %% [markdown]
# **Fit the Data Set**

# %% [markdown]
# import numpy & import matplotlib.pyplot as plt
# → Load libraries for math (numpy) and plotting (matplotlib).
#
# numpy.random.seed(2)
# → Set seed for random number generation (so results are reproducible).
#
# x = numpy.random.normal(3, 1, 100)
# → Generate 100 random numbers for x, from a normal distribution with:
#
# Mean = 3
#
# Std Dev = 1
#
# y = numpy.random.normal(150, 40, 100) / x
# → Generate y values by dividing another set of random numbers by x.
#
# Split data into training and test sets:
#
# train_x = x[:80], train_y = y[:80] → First 80 for training
#
# test_x = x[80:], test_y = y[80:] → Last 20 for testing
#
# mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))
# → Fit a 4th-degree polynomial to the training data (x and y).
# → poly1d creates a function from the polynomial coefficients.
#
# myline = numpy.linspace(0, 6, 100)
# → Generate 100 evenly spaced values between 0 and 6 for plotting the model line.
#
# plt.scatter(train_x, train_y)
# → Plot training data as a scatter plot.
#
# plt.plot(my... → (Incomplete in your code)
# → It should be:

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)
x=numpy.random.normal(3,1,100)
y=numpy.random.normal(150,40,100)/x

train_x=x[:80]
train_y=y[:80]

test_x=x[80:]
test_y=y[80:]

mymodel= numpy.poly1d(numpy.polyfit(train_x,train_y,4))
myline=numpy.linespace(0,6,100)

plt.scatter(train_x,train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# ✅ What is R² (R-squared)?
# R² measures how well the model fits the data.
#
# It ranges from 0 to 1:
#
# 1.0 = Perfect fit
#
# 0.0 = Model explains nothing
#
# Negative value = model is worse than just using the mean

# %% [markdown]
# **Bring in the Testing Set**

# %%
import numpy
from sklearn.metrics import r2_score
numpy.random.seed(2)

x=numpy.random.normal(3,1,100)
y=numpy.random.normal(150,40,100)/x

train_x=x[:80]
train_y=y[:80]

test_x=x[80:]
test_y=y[80:]

mymodel=numpy.poly1d(numpy.polyfit(train_x,train_y,4))
r2=r2_score(test_y,mymodel(test_x))
print(r2)
# Out:
# 0.8086921460343566

# %% [markdown]
# **Predict Values**

# %%
print(mymodel(5))
# Out:
# 22.8796259181172

# %% [markdown]
# **K-means**
#
# K-means is an unsupervised learning method for
# clustering data points. The algorithm iteratively divides
# data points into K clusters by minimizing the variance in
# each cluster.

# %%
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

plt.scatter(x,y)
plt.show()

# %% [markdown]
# Now we utilize the **elbow** method to visualize the intertia for
# different values of K:

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

data = list(zip(x, y))
inertias = []  # spelling also fixed here

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)  # corrected spelling

plt.plot(range(1, 11), inertias, marker='o')
plt.title("Elbow Method")
plt.xlabel('Number of Clusters')  # fixed spelling
plt.ylabel('Inertia')             # fixed spelling
plt.show()

kmeans=KMeans(n_clusters=2)
kmeans.fit(data)

plt.scatter(x,y,c=kmeans.labels_)
plt.show()

# %% [markdown]
# **Naïve Bayes**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns;sns.set()

from sklearn.datasets import make_blobs
X,y=make_blobs(300,2, centers=2,random_state=2,cluster_std=1.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='summer')


from sklearn.naive_bayes import GaussianNB
model_GNB = GaussianNB().fit(X, y)



rng=np.random.RandomState(0)
Xnew=[-6,-14]+[14,18]*rng.rand(2000,2)
ynew=model_GNB.predict(Xnew)

plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='summer')
lim=plt.axis()
plt.scatter(Xnew[:, 0], Xnew[:, 1], c=ynew, s=20, cmap='summer', alpha=0.1)

plt.axis(lim)

yprob=model_GNB.predict_proba(Xnew)
yprob[-10].round(3)
# Out:
# array([0.998, 0.002])
